# %% [markdown]
# ### Limpeza e preparação dos dados
#
# Primeiro, a planilha foi carregada no Python e identificou-se que o cabeçalho estava incorreto, a linha de títulos não correspondia aos nomes das colunas. Para corrigir, a segunda linha do arquivo foi definida como o novo cabeçalho, a linha antiga foi removida e os índices foram reajustados.
#
# Em seguida, várias colunas estavam formatadas como texto. Para identificar quais poderiam ser tratadas como numéricas, foi testada a conversão de cada coluna e calculado o percentual de valores inválidos. As colunas com menos de 5% de falha foram classificadas como numéricas e convertidas automaticamente.
#
# Essa etapa organizou a estrutura da base, padronizou tipos de dados e deixou o conjunto pronto para análises estatísticas mais confiáveis nas próximas fases.

# %%
import pandas as pd

file = "teste1-analise.xlsx"

df = pd.read_excel(file)

df.head()
# Out:
#   Unnamed: 0 LOCALIZAÇÃO Unnamed: 2                       CARACTERIZAÇÃO  \
# 0     ESTADO   MUNICÍPIO   REGIONAL  Com qual gênero você se identifica?
# 1    ALAGOAS   ARAPIRACA      OESTE                             Feminino
# 2    ALAGOAS   ARAPIRACA      OESTE                             Feminino
# 3    ALAGOAS   ARAPIRACA      OESTE                            Masculino
# 4    ALAGOAS   ARAPIRACA      OESTE                            Masculino
#
#             Unnamed: 4                          Unnamed: 5  \
# 0  Qual é a sua idade?  Qual é o seu grau de escolaridade?
# 1          Acima de 60                   Superior completo
# 2              51 - 60                      Médio completo
# 3              31 - 40                          Analfabeto
# 4          Acima de 60                      Médio completo
#
#                            Unnamed: 6                           Unnamed: 7  \
# 0  Quantas pessoas vivem na sua casa?  Qual a renda mensal da sua família?
# 1                                   3                                 5000
# 2                                   2                                 1800
# 3                                   8                          7733.333333
# 4                                   3                                 1500
#
#        Unnamed: 8        Unnamed: 9  ...  \
# 0     Faixa Renda  Renda Per Capita  ...
# 1  De 4501 a 5000       1666.666667  ...
# 2  De 1501 a 2000               900  ...
# 3   Acima de 5000        966.666667  ...
# 4   De 601 a 1500               500  ...
#
#                                          Unnamed: 44  \
# 0  A EMPRESA DE ENERGIA investe na melhoria da qu...
# 1                                                  5
# 2                                                  2
# 3                                                  3
# 4                                                  8
#
#                                          Unnamed: 45  \
# 0  A EMPRESA DE ENERGIA comunica aos seus consumi...
# 1                                                  5
# 2                                                  1
# 3                                                  4
# 4                                                  2
#
#                                          Unnamed: 46  \
# 0  De 1 a 10, a EMPRESA DE ENERGIA combate o cons...
# 1                                                  1
# 2                                                  2
# 3                                                  4
# 4                                                  4
#
#                                          Unnamed: 47  \
# 0  A EMPRESA DE ENERGIA fornece atendimentos sem ...
# 1                                                  5
# 2                                                  5
# 3                                                  2
# 4                                                  2
#
#                                          Unnamed: 48  \
# 0  A EMPRESA DE ENERGIA está disposta a negociar ...
# 1                                                  1
# 2                                                  3
# 3                                                  4
# 4                                                  1
#
#                                     Unnamed: 49  \
# 0  A EMPRESA DE ENERGIA cuida do meio ambiente?
# 1                                             5
# 2                                             2
# 3                                             2
# 4                                             4
#
#                                          Unnamed: 50  \
# 0  A EMPRESA DE ENERGIA é uma empresa preparada o...
# 1                                                  1
# 2                                                  3
# 3                                                  2
# 4                                                  5
#
#                                     SATISFAÇÃO GERAL  \
# 0  Pensando em tudo o que nós falamos até aqui e ...
# 1                                                  5
# 2                                                  2
# 3                                                  2
# 4                                                  5
#
#                                                PREÇO  \
# 0  Quanto mais ou menos você paga por mês em sua ...
# 1                                                310
# 2                                                313
# 3                                                459
# 4                                                386
#
#                                          Unnamed: 53
# 0  Como você considera o valor da conta de energi...
# 1                                                  5
# 2                                                  1
# 3                                                  3
# 4                                                  3
#
# [5 rows x 54 columns]

# %%
novo_header = df.iloc[0]

df = df[1:]

df.columns = novo_header

df = df.reset_index(drop=True)

df.head()
# Out:
# 0   ESTADO  MUNICÍPIO REGIONAL Com qual gênero você se identifica?  \
# 0  ALAGOAS  ARAPIRACA    OESTE                            Feminino
# 1  ALAGOAS  ARAPIRACA    OESTE                            Feminino
# 2  ALAGOAS  ARAPIRACA    OESTE                           Masculino
# 3  ALAGOAS  ARAPIRACA    OESTE                           Masculino
# 4  ALAGOAS  ARAPIRACA    OESTE                            Feminino
#
# 0 Qual é a sua idade? Qual é o seu grau de escolaridade?  \
# 0         Acima de 60                  Superior completo
# 1             51 - 60                     Médio completo
# 2             31 - 40                         Analfabeto
# 3         Acima de 60                     Médio completo
# 4             31 - 40               Fundamental completo
#
# 0 Quantas pessoas vivem na sua casa? Qual a renda mensal da sua família?  \
# 0                                  3                                5000
# 1                                  2                                1800
# 2                                  8                         7733.333333
# 3                                  3                                1500
# 4                                  3                                2100
#
# 0     Faixa Renda Renda Per Capita  ...  \
# 0  De 4501 a 5000      1666.666667  ...
# 1  De 1501 a 2000              900  ...
# 2   Acima de 5000       966.666667  ...
# 3   De 601 a 1500              500  ...
# 4  De 2001 a 2500              700  ...
#
# 0 A EMPRESA DE ENERGIA investe na melhoria da qualidade do fornecimento de energia, ou seja, investe em melhorias do fornecimento de energia, como por exemplo, faz manutenção em transformadores, em fios, em postes etc?  \
# 0                                                  5
# 1                                                  2
# 2                                                  3
# 3                                                  8
# 4                                                  6
#
# 0 A EMPRESA DE ENERGIA comunica aos seus consumidores sobre a sua atuação e atividades realizadas? (Nota de 1 até 10)  \
# 0                                                  5
# 1                                                  1
# 2                                                  4
# 3                                                  2
# 4                                                  5
#
# 0 De 1 a 10, a EMPRESA DE ENERGIA combate o consumo irregular da energia elétrica, por exemplo fraudes como gatos, furto de energia etc?  \
# 0                                                  1
# 1                                                  2
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
# 0 A EMPRESA DE ENERGIA fornece atendimentos sem discriminação ou imparcialidade?  \
# 0                                                  5
# 1                                                  5
# 2                                                  2
# 3                                                  2
# 4                                                  5
#
# 0 A EMPRESA DE ENERGIA está disposta a negociar com seus clientes, como por exemplo em parcelamento de faturas?  \
# 0                                                  1
# 1                                                  3
# 2                                                  4
# 3                                                  1
# 4                                                  2
#
# 0 A EMPRESA DE ENERGIA cuida do meio ambiente?  \
# 0                                            5
# 1                                            2
# 2                                            2
# 3                                            4
# 4                                            1
#
# 0 A EMPRESA DE ENERGIA é uma empresa preparada organizada para atender casos de emergência (enchentes, deslizamentos de terra, incêndio, tempestades muito fortes com muito vento)?  \
# 0                                                  1
# 1                                                  3
# 2                                                  2
# 3                                                  5
# 4                                                  2
#
# 0 Pensando em tudo o que nós falamos até aqui e pensando em uma escala de satisfação de 1 até 10, qual é o seu grau de satisfação geral em relação à EMPRESA DE ENERGIA?   \
# 0                                                  5
# 1                                                  2
# 2                                                  2
# 3                                                  5
# 4                                                  6
#
# 0 Quanto mais ou menos você paga por mês em sua conta de luz?  \
# 0                                                310
# 1                                                313
# 2                                                459
# 3                                                386
# 4                                                489
#
# 0 Como você considera o valor da conta de energia de 1 a 5, onde 1 é muito caro, 3 normal e 5 muito barato?
# 0                                                  5
# 1                                                  1
# 2                                                  3
# 3                                                  3
# 4                                                  2
#
# [5 rows x 54 columns]

# %%
df.dtypes
# Out:
# 0
# ESTADO                                                                                                                                                                                                                                                        object
# MUNICÍPIO                                                                                                                                                                                                                                                     object
# REGIONAL                                                                                                                                                                                                                                                      object
# Com qual gênero você se identifica?                                                                                                                                                                                                                           object
# Qual é a sua idade?                                                                                                                                                                                                                                           object
# Qual é o seu grau de escolaridade?                                                                                                                                                                                                                            object
# Quantas pessoas vivem na sua casa?                                                                                                                                                                                                                             int64
# Qual a renda mensal da sua família?                                                                                                                                                                                                                          float64
# Faixa Renda                                                                                                                                                                                                                                                 category
# Renda Per Capita                                                                                                                                                                                                                                             float64
# Faixa Renda Per Capita                                                                                                                                                                                                                                        object
# Salário utilizado para pagar a conta                                                                                                                                                                                                                          object
# De 1 a 10, qual nota você dá para o fornecimento de energia sem interrupção, ou seja, não faltar luz na sua casa?                                                                                                                                              int64
# De 1 a 10, que nota você dá para a variação da energia, ou seja, sem ficar alternando luz forte com luz fraca na sua casa?                                                                                                                                     int64
# De 1 a 10, qual nota você atribui para a rapidez na volta da energia quando falta energia na sua casa, ou seja, o tempo que leva para a energia voltar, quando falta?                                                                                          int64
# Alguma vez você recebeu algum aviso da EMPRESA DE ENERGIA, informando que você ficaria sem energia, por causa da realização de serviços para melhorar a rede elétrica?                                                                                        object
# Caso sim, como você ficou sabendo que a falta de energia aconteceu por causa de um serviço de melhoria da rede elétrica que tinha sido programado pela EMPRESA DE ENERGIA? (Citar os possíveis canais para medir qual o meio de comunicação mais eficaz)      object
# De 1 a 10, como você avalia o aviso recebido?                                                                                                                                                                                                                 object
# A EMPRESA DE ENERGIA fornece orientações para evitar o desperdício de energia?                                                                                                                                                                                 int64
# A EMPRESA DE ENERGIA orienta o cliente sobre a medição do consumo de energia, ou seja, como se faz a leitura do medidor?                                                                                                                                       int64
# A EMPRESA DE ENERGIA informa aos clientes sobre os riscos e perigos da rede elétrica?                                                                                                                                                                          int64
# A EMPRESA DE ENERGIA esclarece aos clientes sobre seus direitos e deveres?                                                                                                                                                                                     int64
# Você recebe mensalmente sua conta de luz?                                                                                                                                                                                                                     object
# Por onde você recebe sua conta de luz?                                                                                                                                                                                                                        object
# Dê uma nota de 1 até 10 para o prazo entre o recebimento da conta e o vencimento (pagamento) da conta.                                                                                                                                                         int64
# Dê uma nota de 1 até 10 para a conta de luz sem erros, ou seja, com a leitura do seu consumo correta.                                                                                                                                                          int64
# Dê uma nota de 1 até 10 para a facilidade no entendimento das informações que estão na conta de luz.                                                                                                                                                           int64
# Dê uma nota de 1 até 10 para a disponibilidade de locais para pagamento (tais como bancos, internet, correios, rede comercial conveniada tais como supermercados, farmácias dentre outros).                                                                    int64
# Dê uma nota de 1 até 10 para a data de vencimento da conta de luz.                                                                                                                                                                                             int64
# Você sabia que é possível alterar a data do vencimento da sua fatura?                                                                                                                                                                                         object
# Mudar a data do vencimento te ajudaria?                                                                                                                                                                                                                       object
# Você já entrou em contato com a EMPRESA DE ENERGIA, qual o canal de comunicação foi utilizado? (qual canal?)                                                                                                                                                  object
# Qual serviço foi solicitado?                                                                                                                                                                                                                                  object
# Dê uma nota de 1 até 10 para a facilidade para entrar em contato com a empresa quando quiser pedir informações ou serviços.                                                                                                                                    int64
# Qual nota você atribui para o tempo de espera de atendimento da EMPRESA DE ENERGIA, seja por telefone, agência EMPRESA DE ENERGIA ou colaborador em campo (eletricista, leiturista etc). (notas de 1 até 10)                                                   int64
# Qual nota você atribui a agilidade/rapidez do atendimento ao consumidor (pessoa que o atende por telefone ou na agência da EMPRESA DE ENERGIA)? (nota de 1 até 10)                                                                                             int64
# De 1 a 10, qual nota você atribui para o conhecimento que os colaboradores EMPRESA DE ENERGIA têm sobre o assunto, sobre conseguir responder suas dúvidas.                                                                                                     int64
# De 1 a 10, qual nota você atribui para facilidade de entendimento das informações dadas pela EMPRESA DE ENERGIA (as informações são claras e fáceis de entender)?                                                                                              int64
# De 1 a 10, qual nota você atribui para a educação e gentileza da equipe?                                                                                                                                                                                       int64
# Dê uma nota de 1 até 10 para o prazo informado pela empresa para a realização dos serviços solicitados pelo consumidor.                                                                                                                                        int64
# Dê uma nota de 1 até 10 para solução definitiva do problema, ou seja, resolver o problema de uma vez.                                                                                                                                                          int64
# Dê uma nota de 1 até 10 para o cumprimento do prazo informado pela empresa para resolver as solicitações dos consumidores.                                                                                                                                     int64
# A EMPRESA DE ENERGIA respeita os direitos dos consumidores?                                                                                                                                                                                                    int64
# A EMPRESA DE ENERGIA é justa com os consumidores?                                                                                                                                                                                                              int64
# A EMPRESA DE ENERGIA investe na melhoria da qualidade do fornecimento de energia, ou seja, investe em melhorias do fornecimento de energia, como por exemplo, faz manutenção em transformadores, em fios, em postes etc?                                       int64
# A EMPRESA DE ENERGIA comunica aos seus consumidores sobre a sua atuação e atividades realizadas? (Nota de 1 até 10)                                                                                                                                            int64
# De 1 a 10, a EMPRESA DE ENERGIA combate o consumo irregular da energia elétrica, por exemplo fraudes como gatos, furto de energia etc?                                                                                                                         int64
# A EMPRESA DE ENERGIA fornece atendimentos sem discriminação ou imparcialidade?                                                                                                                                                                                 int64
# A EMPRESA DE ENERGIA está disposta a negociar com seus clientes, como por exemplo em parcelamento de faturas?                                                                                                                                                  int64
# A EMPRESA DE ENERGIA cuida do meio ambiente?                                                                                                                                                                                                                   int64
# A EMPRESA DE ENERGIA é uma empresa preparada organizada para atender casos de emergência (enchentes, deslizamentos de terra, incêndio, tempestades muito fortes com muito vento)?                                                                              int64
# SATISFACAO_GERAL                                                                                                                                                                                                                                               int64
# Quanto mais ou menos você paga por mês em sua conta de luz?                                                                                                                                                                                                    int64
# Como você considera o valor da conta de energia de 1 a 5, onde 1 é muito caro, 3 normal e 5 muito barato?                                                                                                                                                    float64
# PerCapitaCategoria                                                                                                                                                                                                                                          category
# Comprometimento (%)                                                                                                                                                                                                                                          float64
# UF                                                                                                                                                                                                                                                            object
# dtype: object

# %%
# Informações básicas do dataset
print("INFORMAÇÕES GERAIS DO DATASET")
print("\n")
print("Total de linhas:", df.shape[0])
print("Total de colunas:", df.shape[1])

print("\n")
print("VALORES AUSENTES")
print("\n")

missing = df.isnull().sum()
missing_percent = (df.isnull().sum() / len(df)) * 100

missing_df = pd.DataFrame({
    'Coluna': missing.index,
    'Missing': missing.values,
    'Percentual': missing_percent.values
})

missing_df = missing_df[missing_df['Missing'] > 0].sort_values('Missing', ascending=False)

if len(missing_df) > 0:
    print(missing_df.to_string(index=False))
else:
    print("Nenhum valor ausente encontrado")
# Out:
# INFORMAÇÕES GERAIS DO DATASET
#
#
# Total de linhas: 400
# Total de colunas: 57
#
#
# VALORES AUSENTES
#
#
#                                                                                                                                                                                                                                                   Coluna  Missing  Percentual
# Caso sim, como você ficou sabendo que a falta de energia aconteceu por causa de um serviço de melhoria da rede elétrica que tinha sido programado pela EMPRESA DE ENERGIA? (Citar os possíveis canais para medir qual o meio de comunicação mais eficaz)      214        53.5
#                                                                                                                                                                                                            De 1 a 10, como você avalia o aviso recebido?      214        53.5
#                                                                                                                                                                                                                             Qual serviço foi solicitado?       38         9.5
#                                                                                                                                                Como você considera o valor da conta de energia de 1 a 5, onde 1 é muito caro, 3 normal e 5 muito barato?        2         0.5

# %%
# Perfil demográfico
print("PERFIL DEMOGRAFICO DA AMOSTRA")
print("\n")

print("GENERO:")
print(df['Com qual gênero você se identifica?'].value_counts())
print("\n")

print("FAIXA ETARIA:")
print(df['Qual é a sua idade?'].value_counts().sort_index())
print("\n")

print("ESCOLARIDADE:")
print(df['Qual é o seu grau de escolaridade?'].value_counts())
print("\n")

print("DISTRIBUICAO GEOGRAFICA:")
print("Total de Estados:", df['ESTADO'].nunique())
print(df['ESTADO'].value_counts())
# Out:
# PERFIL DEMOGRAFICO DA AMOSTRA
#
#
# GENERO:
# Com qual gênero você se identifica?
# Feminino     217
# Masculino    183
# Name: count, dtype: int64
#
#
# FAIXA ETARIA:
# Qual é a sua idade?
# 18 - 30         75
# 31 - 40        125
# 41 - 50         75
# 51 - 60         50
# Acima de 60     75
# Name: count, dtype: int64
#
#
# ESCOLARIDADE:
# Qual é o seu grau de escolaridade?
# Médio completo                        140
# Fundamental completo                   72
# Superior completo                      69
# Analfabeto                             48
# Fundamental incompleto                 48
# Pós Graduação/ Mestrado/ Doutorado     23
# Name: count, dtype: int64
#
#
# DISTRIBUICAO GEOGRAFICA:
# Total de Estados: 4
# ESTADO
# ALAGOAS     100
# MARANHÃO    100
# PARÁ        100
# PIAUÍ       100
# Name: count, dtype: int64

# %%
# Análise de renda
print("ANALISE DE RENDA")
print("\n")

print("RENDA FAMILIAR - Estatísticas:")
print(df['Qual a renda mensal da sua família?'].describe())
print("\n")

print("DISTRIBUICAO POR FAIXA DE RENDA:")
print(df['Faixa Renda'].value_counts().sort_index())
print("\n")

print("RENDA PER CAPITA - Estatísticas:")
print(df['Renda Per Capita'].describe())
print("\n")

print("DISTRIBUICAO POR FAIXA RENDA PER CAPITA:")
print(df['Faixa Renda Per Capita'].value_counts())
print("\n")

print("COMPROMETIMENTO COM ENERGIA - Estatísticas:")
print(df['Comprometimento (%)'].describe())
# Out:
# ANALISE DE RENDA
#
#
# RENDA FAMILIAR - Estatísticas:
# count      400.000000
# mean      3229.583333
# std       1675.431371
# min        600.000000
# 25%       2000.000000
# 50%       2666.666667
# 75%       4000.000000
# max      10666.666667
# Name: Qual a renda mensal da sua família?, dtype: float64
#
#
# DISTRIBUICAO POR FAIXA DE RENDA:
# Faixa Renda
# Até 600            4
# De 601 a 1500     33
# De 1501 a 2000    71
# De 2001 a 2500    68
# De 2501 a 3000    56
# De 3001 a 3500    32
# De 3501 a 4000    53
# De 4001 a 4500     5
# De 4501 a 5000    33
# Acima de 5000     45
# Name: count, dtype: int64
#
#
# RENDA PER CAPITA - Estatísticas:
# count     400.000000
# mean     1146.562500
# std       760.489047
# min       200.000000
# 25%       666.666667
# 50%       833.333333
# 75%      1333.333333
# max      5000.000000
# Name: Renda Per Capita, dtype: float64
#
#
# DISTRIBUICAO POR FAIXA RENDA PER CAPITA:
# Faixa Renda Per Capita
# De 1001 a 1500    78
# De 601 a 700      58
# De 701 a 800      49
# De 1501 a 2000    45
# De 501 a 600      42
# Acima de 2000     39
# De 901 a 1000     32
# De 401 a 500      31
# De 801 a 900      20
# De 101 a 200       4
# De 201 a 300       1
# De 301 a 400       1
# Name: count, dtype: int64
#
#
# COMPROMETIMENTO COM ENERGIA - Estatísticas:
# count    400.000000
# mean      13.065915
# std        8.835924
# min        1.659375
# 25%        7.624597
# 50%       10.995455
# 75%       16.458534
# max       82.166667
# Name: Comprometimento (%), dtype: float64

# %%
# Criando categorias de vulnerabilidade
print("ANALISE DE VULNERABILIDADE")
print("\n")

# Definir grupos vulneráveis
vulneravel_renda = df[df['Renda Per Capita'] <= 833]
alto_comprometimento = df[df['Comprometimento (%)'] > 10]

print("PESSOAS EM VULNERABILIDADE:")
print("Renda per capita ate R$ 833 (50% mais pobres):", len(vulneravel_renda))
print("Comprometimento acima de 10% (pobreza energetica):", len(alto_comprometimento))
print("\n")

# Cruzamento renda x escolaridade
print("RENDA PER CAPITA POR ESCOLARIDADE:")
print(df.groupby('Qual é o seu grau de escolaridade?')['Renda Per Capita'].agg(['mean', 'median', 'count']))
print("\n")

# Comprometimento por faixa de renda
print("COMPROMETIMENTO POR FAIXA DE RENDA:")
print(df.groupby('Faixa Renda')['Comprometimento (%)'].agg(['mean', 'median']))
# Out:
# ANALISE DE VULNERABILIDADE
#
#
# PESSOAS EM VULNERABILIDADE:
# Renda per capita ate R$ 833 (50% mais pobres): 193
# Comprometimento acima de 10% (pobreza energetica): 229
#
#
# RENDA PER CAPITA POR ESCOLARIDADE:
#                                            mean       median  count
# Qual é o seu grau de escolaridade?
# Analfabeto                           883.680556   733.333333     48
# Fundamental completo                1051.851852   800.000000     72
# Fundamental incompleto              1031.250000   800.000000     48
# Médio completo                       882.202381   666.666667    140
# Pós Graduação/ Mestrado/ Doutorado  1694.927536  1333.333333     23
# Superior completo                   1862.077295  1500.000000     69
#
#
# COMPROMETIMENTO POR FAIXA DE RENDA:
#                      mean     median
# Faixa Renda
# Até 600         65.916667  70.750000
# De 601 a 1500   23.183761  22.600000
# De 1501 a 2000  17.287056  16.166667
# De 2001 a 2500  15.491695  15.350476
# De 2501 a 3000  12.062193  11.568750
# De 3001 a 3500   9.058572   8.637829
# De 3501 a 4000   8.972973   9.350000
# De 4001 a 4500   7.758030   8.704545
# De 4501 a 5000   6.848617   6.958333
# Acima de 5000    4.691103   4.155000
# /tmp/ipykernel_28952/4058028652.py:21: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %%
# Análise de satisfação
print("ANALISE DE SATISFACAO GERAL")
print("\n")

print("ESTATISTICAS DA SATISFACAO GERAL:")
print(df['SATISFACAO_GERAL'].describe())
print("\n")

print("DISTRIBUICAO DAS NOTAS:")
print(df['SATISFACAO_GERAL'].value_counts().sort_index())
print("\n")

print("SATISFACAO POR FAIXA DE RENDA:")
print(df.groupby('Faixa Renda')['SATISFACAO_GERAL'].agg(['mean', 'median', 'count']))
print("\n")

print("SATISFACAO POR ESCOLARIDADE:")
print(df.groupby('Qual é o seu grau de escolaridade?')['SATISFACAO_GERAL'].agg(['mean', 'median']))
# Out:
# ANALISE DE SATISFACAO GERAL
#
#
# ESTATISTICAS DA SATISFACAO GERAL:
# count    400.000000
# mean       5.570000
# std        2.795467
# min        1.000000
# 25%        3.000000
# 50%        5.000000
# 75%        8.000000
# max       10.000000
# Name: SATISFACAO_GERAL, dtype: float64
#
#
# DISTRIBUICAO DAS NOTAS:
# SATISFACAO_GERAL
# 1     41
# 2     33
# 3     32
# 4     30
# 5     65
# 6     46
# 7     36
# 8     42
# 9     34
# 10    41
# Name: count, dtype: int64
#
#
# SATISFACAO POR FAIXA DE RENDA:
#                     mean  median  count
# Faixa Renda
# Até 600         6.750000     8.0      4
# De 601 a 1500   5.333333     5.0     33
# De 1501 a 2000  5.605634     6.0     71
# De 2001 a 2500  5.573529     5.5     68
# De 2501 a 3000  5.696429     5.0     56
# De 3001 a 3500  5.968750     6.0     32
# De 3501 a 4000  4.849057     5.0     53
# De 4001 a 4500  6.200000     8.0      5
# De 4501 a 5000  5.303030     5.0     33
# Acima de 5000   6.111111     7.0     45
#
#
# SATISFACAO POR ESCOLARIDADE:
#                                         mean  median
# Qual é o seu grau de escolaridade?
# Analfabeto                          5.666667     5.5
# Fundamental completo                5.208333     5.0
# Fundamental incompleto              5.833333     5.5
# Médio completo                      5.764286     6.0
# Pós Graduação/ Mestrado/ Doutorado  5.826087     5.0
# Superior completo                   5.217391     5.0
# /tmp/ipykernel_28952/3019952523.py:14: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %%
# Análise de correlação - Dimensões de qualidade
import numpy as np

# Selecionar variáveis de qualidade (notas 1-10)
qualidade_cols = [
    'De 1 a 10, qual nota você dá para o fornecimento de energia sem interrupção, ou seja, não faltar luz na sua casa?',
    'De 1 a 10, que nota você dá para a variação da energia, ou seja, sem ficar alternando luz forte com luz fraca na sua casa?',
    'De 1 a 10, qual nota você atribui para a rapidez na volta da energia quando falta energia na sua casa, ou seja, o tempo que leva para a energia voltar, quando falta?'
]

# Calcular correlação com satisfação geral
print("CORRELACAO COM SATISFACAO GERAL - QUALIDADE DO FORNECIMENTO:")
print("\n")
for col in qualidade_cols:
    corr = df[col].corr(df['SATISFACAO_GERAL'])
    print(f"Correlacao: {corr:.3f}")
    print(f"Variavel: {col[:80]}...")
    print("\n")

# Médias por dimensão
print("MEDIAS DAS NOTAS DE QUALIDADE:")
print(df[qualidade_cols].mean())
# Out:
# CORRELACAO COM SATISFACAO GERAL - QUALIDADE DO FORNECIMENTO:
#
#
# Correlacao: 0.069
# Variavel: De 1 a 10, qual nota você dá para o fornecimento de energia sem interrupção, ou ...
#
#
# Correlacao: -0.016
# Variavel: De 1 a 10, que nota você dá para a variação da energia, ou seja, sem ficar alter...
#
#
# Correlacao: 0.041
# Variavel: De 1 a 10, qual nota você atribui para a rapidez na volta da energia quando falt...
#
#
# MEDIAS DAS NOTAS DE QUALIDADE:
# 0
# De 1 a 10, qual nota você dá para o fornecimento de energia sem interrupção, ou seja, não faltar luz na sua casa?                                                        6.5000
# De 1 a 10, que nota você dá para a variação da energia, ou seja, sem ficar alternando luz forte com luz fraca na sua casa?                                               5.6250
# De 1 a 10, qual nota você atribui para a rapidez na volta da energia quando falta energia na sua casa, ou seja, o tempo que leva para a energia voltar, quando falta?    6.7475
# dtype: float64
